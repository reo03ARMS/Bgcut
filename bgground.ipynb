# %%
from rembg import remove
import cv2
from matplotlib import pyplot as plt
# %matplotlib inline

input_img = cv2.imread('test.jpeg',0)

plt.imshow(input_img)
plt.show()

# %%
#背景削除
bgcut = remove(input_img)
plt.imshow(bgcut)
plt.show()
